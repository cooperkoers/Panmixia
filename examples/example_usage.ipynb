# %%
import sys
from pathlib import Path

project_root = Path().resolve().parent
sys.path.append(str(project_root / "src"))

# %%
import Panmixia as pmx

# %%
pmx.NaivePopulationSimulator(n0=200, n1=10, L=1000, mate_bias=1, plotting=False).simulate(generations=10)
# Out:
# Generation 1: Average Ancestry = 0.0976
# Generation 1: Std Deviation Ancestry = 0.2099
# Generation 2: Average Ancestry = 0.1249
# Generation 2: Std Deviation Ancestry = 0.1945
# Generation 3: Average Ancestry = 0.1663
# Generation 3: Std Deviation Ancestry = 0.2064
# Generation 4: Average Ancestry = 0.1924
# Generation 4: Std Deviation Ancestry = 0.1982
# Generation 5: Average Ancestry = 0.2206
# Generation 5: Std Deviation Ancestry = 0.1786
# Generation 6: Average Ancestry = 0.2262
# Generation 6: Std Deviation Ancestry = 0.1678
# Generation 7: Average Ancestry = 0.2594
# Generation 7: Std Deviation Ancestry = 0.1773
# Generation 8: Average Ancestry = 0.2782
# Generation 8: Std Deviation Ancestry = 0.1682
# Generation 9: Average Ancestry = 0.3186
# Generation 9: Std Deviation Ancestry = 0.1700
# Generation 10: Average Ancestry = 0.3498
# Generation 10: Std Deviation Ancestry = 0.1641
